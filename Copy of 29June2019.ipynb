# %%
import pandas as pd
a = pd.Series([1,3,4,5,6,7])
print(a)
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
# Missing Values then it can be nan of nampy
import numpy as np
a1 = pd.Series([1,2,3,4,np.nan,6])
print(a1)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    6.0
# dtype: float64

# %%
import pandas as pd
a=pd.Series([1,3,4,5,6,7])
print(a)
import numpy as np
a1=pd.Series([1,2,3,4,np.nan,6])
print(a1)
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    6.0
# dtype: float64

# %%
dates = pd.date_range('20190601',periods=20)
print(dates)
# Out:
# DatetimeIndex(['2019-06-01', '2019-06-02', '2019-06-03', '2019-06-04',
#                '2019-06-05', '2019-06-06', '2019-06-07', '2019-06-08',
#                '2019-06-09', '2019-06-10', '2019-06-11', '2019-06-12',
#                '2019-06-13', '2019-06-14', '2019-06-15', '2019-06-16',
#                '2019-06-17', '2019-06-18', '2019-06-19', '2019-06-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
a3=pd.datesFrame({'A':1.,
                 'B':pd.timestamp('20190601'),
                 'C':pd.series(1,index=list(range(4)),dtype='float32'),
                 'D':np.array([3]*4,dtype='int32'),
                 'E':pd.categorical(["test","train","test","train"]),
                 'F':foo})

# %%
#turtle is a python feature like a drawing board
#lines,square,stars,react,etc,
#--turtle--it creates and returns a new turtle object

# %%
#step 1: make all the turtles packages to be imported
import turtle as tt
#turtle method creates and returns the new object
a1=tt.turtle
